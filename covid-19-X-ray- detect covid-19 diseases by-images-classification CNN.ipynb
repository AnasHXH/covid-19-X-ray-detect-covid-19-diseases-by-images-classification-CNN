# %% [markdown]
# # Datasets
# https://data.mendeley.com/datasets/8h65ywd2jr/1?fbclid=IwAR1726GnO89IIABFXwNWdileS3X7U4H8ZPcyZLb04fZMx4CX7fU1B6Ln1Do
# This COVID-19 dataset consists of Non-COVID and COVID cases of both X-ray and CT images. The associated dataset is augmented with different augmentation techniques to generate about 17100 X-ray and CT images. The dataset contains two main folders, one for the X-ray images, which includes two separate sub-folders of 5500 Non-COVID images and 4045 COVID images. The other folder contains the CT images. It includes two separate sub-folders of 2628 Non-COVID images and 5427 COVID images
# ### Contributor(s): Walid El-Shafai, Fathi E. Abd El-Samie
# And Datasets of PNEUMONIA from :direct link
# https://storage.googleapis.com/kaggle-data-sets/587326%2F1059612%2Fcompressed%2FChest_xray_image_dataset_covid_19_and_others.zip?GoogleAccessId=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com&Expires=1591929916&Signature=LS5l%2FL4g0DdqM9tYatgTKmxtSbERduZ1mqXZzM7HTP0ErmJla1zfTOJNcy4ZiSM7zHKLHm3jI40WUYaweaIB5hNBkepdvUs0zSrIBVuCIuJb1xXrMRlPzvjOaBzVSwCu0ThJRQ8x8Rs7zIFm%2F2JTHVSLyHmqrUw2I4xRHodsGOU8I9GWRPbO02aUZU8yN5JNL1xa6cUYh0BLzvv97zzYr1xolktnUEmp9C4%2BLxMtDIFdC9srqXbvs3GVugxYgO3UEDPrLwt5ZZCFm4D3Fpr2xvUwR4FiO2%2BW7xpYeSWYhtgQ8LYBg3ZmCRA%2BMWLb6jVgEZC8sHsIbxziexotNZ8eYw%3D%3D

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
import os
import glob as gb
import cv2
import tensorflow as tf
from tqdm import tqdm
import keras
from PIL import Image
import math
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Separate Datasets of Covid-19 to train and test and predict
# ### In this section we 'll Preparation Datasets to image processing which converts Extention to.PNG because datasets have many image file formats and save it in 3 folders (train, test, predict )

# %% [markdown]
# ### Folder Covid-19
# #### train -->60%
# #### test -->25%
# #### predict -->10%

# %%
#Creat folder to save a new data
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train')
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test')

# %%
path='C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/X-ray/COVID/*.*'
 
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/COVID-19')
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/COVID-19')
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Predict')
files = gb.glob(pathname= str(path))
l=len(files)
i=1
################################################
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/COVID-19//{i}.png', image)
    precentage=math.floor((60/100) * l)
    if i == precentage:
        break
    else:
        i+=1
###################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/COVID-19//{i}.png', image)
    precentage=math.floor((85/100) * l)
    if i == precentage:
        break
    else:
        i+=1
#####################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Predict//cov1{i}.png', image)
    precentage=math.floor((10/10) * l)
    if i == precentage:
        break
    else:
        i+=1
#Add more data from another folder((Optionals))
i+=1
files2 = gb.glob(pathname= str('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Covid_19/*.*'))
for file in files2: 
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Predict//cov2{i}.png', image)
    precentage=math.floor((10/10) * l)
    if i == precentage:
        break
    else:
        i+=1

# %% [markdown]
# ### Folder Normal
# #### train -->60%
# #### test -->30%
# #### predict -->10%

# %%
path='C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/X-ray/NORMAL/*.*'
#to creat folder to save a new data 
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/NORMAL')
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/NORMAL')

files = gb.glob(pathname= str(path))
l=len(files)
i=1
################################################
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/NORMAL//{i}.png', image)
    precentage=math.floor((6/10) * l)
    if i == precentage:
        break
    else:
        i+=1
###################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/NORMAL//{i}.png', image)
    precentage=math.floor((9/10) * l)
    if i == precentage:
        break
    else:
        i+=1
#####################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Predict//nor{i}.png', image)
    precentage=math.floor((10/10) * l)
    if i == precentage:
        break
    else:
        i+=1

# %% [markdown]
# ### Folder PNEUMONIA
# #### train -->60%
# #### test -->30%
# #### predict -->10%

# %%
path='C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/X-ray/PNEUMONIA/*.*'
#to creat folder to save a new data 
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/PNEUMONIA')
os.mkdir('C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/PNEUMONIA')

files = gb.glob(pathname= str(path))
l=len(files)
i=1
################################################
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/train/PNEUMONIA//{i}.png', image)
    precentage=math.floor((6/10) * l)
    if i == precentage:
        break
    else:
        i+=1
###################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/test/PNEUMONIA//{i}.png', image)
    precentage=math.floor((9/10) * l)
    if i == precentage:
        break
    else:
        i+=1
#####################################
i+=1
for file in files:  
    image = cv2.imread(file)
    conimg=cv2.imwrite( f'C:/Users/Anas/CNN-master/Covid-19_By_Anas_Magdy/Predict//pne{i}.png', image)
    precentage=math.floor((10/10) * l)
    if i == precentage:
        break
    else:
        i+=1

# %% [markdown]
# ### ====================================================================================

# %% [markdown]
# # Open Folders((Optional))
#
# ### now let's first check the train folder to have a look to its content

# %%
for folder in  os.listdir('train//') : 
    files = gb.glob(pathname= str( 'train//' + folder + '/*.*'))
    print(f'For training data , found {len(files)} in folder {folder}')
# Out:
# For training data , found 2426 in folder COVID-19
# For training data , found 2364 in folder NORMAL
# For training data , found 2563 in folder PNEUMONIA

# %% [markdown]
# ### now let's first check the test folder to have a look to its content

# %%
for folder in  os.listdir('test//') : 
    files = gb.glob(pathname= str( 'test//' + folder + '/*.*'))
    print(f'For training data , found {len(files)} in folder {folder}')
# Out:
# For training data , found 1011 in folder COVID-19
# For training data , found 1182 in folder NORMAL
# For training data , found 1282 in folder PNEUMONIA

# %% [markdown]
# ### now let's first check the train folder to have a look to its content

# %%
files = gb.glob(pathname= str('Predict/*.*'))
print(f'For Prediction data , found {len(files)}')
# Out:
# For Prediction data , found 1669

# %% [markdown]
# ### ====================================================================================

# %% [markdown]
# # Checking Images
#
# now we need to check the images sizes , to know ow they looks like
#
# since we have 3 categories , we first need to create a dictionary with their names & indices , also create a function to get the code back

# %% [markdown]
# ### There are two encoder for label :
# #### 1-label encoder which means every label has desimal number
# #### 2-one hot encoder which means every label has code like (COVID-19:100,NORMAL:010,PNEUMONIA:001)

# %%
#used label encoder
code = {'COVID-19':0 ,'NORMAL':1,'PNEUMONIA':2}

def getcode(n) : 
    for x , y in code.items() : 
        if n == y : 
            return x

# %% [markdown]
# ### now how about the images sizes in train folder

# %%
size = []
for folder in  tqdm(os.listdir('train')) : 
    files = gb.glob(pathname= str('train//' + folder + '/*.png'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# 100%|██████████| 3/3 [05:49<00:00, 116.58s/it]
# (1024, 1024, 3)    2661
# (524, 640, 3)       134
# (2000, 2000, 3)      88
# (842, 1024, 3)       17
# (1550, 1598, 3)      13
#                    ...
# (1128, 1600, 3)       1
# (736, 1168, 3)        1
# (1256, 1624, 3)       1
# (1913, 2252, 3)       1
# (211, 239, 3)         1
# Length: 3275, dtype: int64

# %% [markdown]
# ### now how about the images sizes in test folder

# %%
size = []
for folder in  tqdm(os.listdir('test')) : 
    files = gb.glob(pathname= str('test//' + folder + '/*.png'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# 100%|██████████| 3/3 [03:12<00:00, 64.08s/it]
# (1024, 1024, 3)    532
# (524, 640, 3)      121
# (2000, 2000, 3)     75
# (842, 1024, 3)      14
# (399, 466, 3)       12
#                   ...
# (1764, 2093, 3)      1
# (984, 1208, 3)       1
# (1109, 1616, 3)      1
# (440, 750, 3)        1
# (519, 790, 3)        1
# Length: 2082, dtype: int64

# %% [markdown]
# ### now how about the images sizes in Predict folder

# %%
size = []
files = gb.glob(pathname= str('Predict/*.png'))
for file in files: 
    image = plt.imread(file)
    size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# (1024, 1024, 3)    411
# (524, 640, 3)       98
# (2000, 2000, 3)     62
# (842, 1024, 3)      16
# (659, 651, 3)       12
#                   ...
# (1408, 1752, 3)      1
# (696, 1152, 3)       1
# (1024, 1223, 3)      1
# (863, 1244, 3)       1
# (519, 790, 3)        1
# Length: 804, dtype: int64

# %% [markdown]
# ### ====================================================================================

# %% [markdown]
# # Reading Images
#
# now it's time to read all images & convert it into arrays
#
# first we'll create a variable s , which refer to size , so we can change it easily
#
# let's use now size = 150 , so it will be suitable amount to contain accuracy without losing so much time in training

# %%
s=125

# %%
X_train = []
y_train = []
for folder in  tqdm(os.listdir('train')) : 
    files = gb.glob(pathname= str( 'train//' + folder + '/*.png'))
    for file in files: 
        image = cv2.imread(file)
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image_array = cv2.resize(gray_image , (s,s), interpolation = cv2.INTER_AREA)
        X_train.append(list(image_array))
        y_train.append(code[folder])
# Out:
# 100%|██████████| 3/3 [04:00<00:00, 80.12s/it]

# %%
print(f'we have {len(X_train)} items in X_train')
# Out:
# we have 7353 items in X_train

# %%
plt.figure(figsize=(30,30))
for n , i in enumerate(list(np.random.randint(0,len(X_train),16))) : 
    plt.subplot(8,8,n+1)
    plt.imshow(X_train[i]) 
    plt.gray()
    plt.axis('off')
    plt.title(getcode(y_train[i]), fontsize=18)

# %%
X_test = []
y_test = []
for folder in  tqdm(os.listdir('test')) : 
    files = gb.glob(pathname= str('test//' + folder + '/*.png'))
    for file in files: 
        image = cv2.imread(file)
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image_array = cv2.resize(gray_image , (s,s), interpolation = cv2.INTER_AREA)
        X_test.append(list(image_array))
        y_test.append(code[folder])
# Out:
# 100%|██████████| 3/3 [02:10<00:00, 43.35s/it]

# %%
print(f'we have {len(X_test)} items in X_test')
# Out:
# we have 3475 items in X_test

# %%
plt.figure(figsize=(30,30))
for n , i in enumerate(list(np.random.randint(0,len(X_test),16))) : 
    plt.subplot(8,8,n+1)
    plt.imshow(X_train[i]) 
    plt.gray()
    plt.axis('off')
    plt.title(getcode(y_test[i]), fontsize=18)

# %%
X_pred = []
files = gb.glob(pathname= str('Predict/*.png'))
for file in files: 
    image = cv2.imread(file)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_array = cv2.resize(gray_image , (s,s), interpolation = cv2.INTER_AREA)
    X_pred.append(list(image_array))

# %%
print(f'we have {len(X_pred)} items in X_pred')
# Out:
# we have 1669 items in X_pred

# %%
plt.figure(figsize=(30,30))
for n , i in enumerate(list(np.random.randint(0,len(X_pred),16))) : 
    plt.subplot(8,8,n+1)
    plt.imshow(X_pred[i]) 
    plt.gray()
    plt.axis('off')

# %% [markdown]
# ### ====================================================================================

# %% [markdown]
# # Building The Model
#
# now we need to build the model to train our data
#
# first to convert the data into arrays using numpy

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
X_pred_array = np.array(X_pred)
y_train = np.array(y_train)
y_test = np.array(y_test)

print(f'X_train shape  is {X_train.shape}')
print(f'X_test shape  is {X_test.shape}')
print(f'X_pred shape  is {X_pred_array.shape}')
print(f'y_train shape  is {y_train.shape}')
print(f'y_test shape  is {y_test.shape}')
# Out:
# X_train shape  is (7353, 125, 125)
# X_test shape  is (3475, 125, 125)
# X_pred shape  is (1669, 125, 125)
# y_train shape  is (7353,)
# y_test shape  is (3475,)

# %%
#from keras.utils import to_categorical
#y_train1 = to_categorical(y_train)
#print(y_train1.shape)
#Keras need data in 4 dimention
# Reshape image in 3 dimensions (height = 28px, width = 28px , channels = 1)
X_train = X_train.reshape(-1,s,s,1)
X_test = X_test.reshape(-1,s,s,1)
X_pred_array = X_pred_array.reshape(-1,s,s,1)
print(X_train.shape)
print(X_test.shape)
print(X_pred_array.shape)
# Out:
# (7353, 125, 125, 1)
# (3475, 125, 125, 1)
# (1669, 125, 125, 1)

# %%
KerasModel = keras.models.Sequential([
        keras.layers.BatchNormalization(input_shape=(s,s,1)),
        keras.layers.Conv2D(256,kernel_size=(3,3), padding='same',activation='relu',input_shape=(s,s,1)),
        keras.layers.Conv2D(128,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(2,2),
        keras.layers.Dropout(rate=0.25),
    
        keras.layers.Conv2D(128,kernel_size=(3,3), padding='same',activation='relu'),    
        keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu'),    
        keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(2,2),
        keras.layers.Dropout(rate=0.25),
    
        keras.layers.Flatten() ,    
        keras.layers.Dense(128,activation='relu') ,    
        keras.layers.Dense(64,activation='relu') ,    
        keras.layers.Dense(32,activation='relu') ,        
        keras.layers.Dropout(rate=0.25) ,            
        keras.layers.Dense(3,activation='softmax') ,    
        ])

# %%
KerasModel.compile(optimizer ='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
print('Model Details are : ')
print(KerasModel.summary())
# Out:
# Model Details are :
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_3 (Batch (None, 125, 125, 1)       4
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 125, 125, 256)     2560
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 123, 123, 128)     295040
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 61, 61, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 61, 61, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 61, 61, 128)       147584
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 59, 59, 64)        73792
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 57, 57, 32)        18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 28, 28, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               3211392
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 3,759,271
# Trainable params: 3,759,269
# Non-trainable params: 2
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

model_chkpt = ModelCheckpoint('best_mod.h5', save_best_only=True, monitor='accuracy')
early_stopping = EarlyStopping(monitor='loss', restore_best_weights=False, patience=10)

# %%
epochs = 20
ThisModel = KerasModel.fit(X_train, y_train, epochs=epochs,batch_size=12,verbose=1,
                            validation_split=0.20,
                            shuffle=True, 
                            callbacks=[model_chkpt ,early_stopping])
# Out:
# Train on 5882 samples, validate on 1471 samples
# Epoch 1/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.6112 - accuracy: 0.7242 - val_loss: 0.3737 - val_accuracy: 0.9422
# Epoch 2/20
# 5882/5882 [==============================] - 231s 39ms/step - loss: 0.4466 - accuracy: 0.8184 - val_loss: 0.8339 - val_accuracy: 0.7029
# Epoch 3/20
# 5882/5882 [==============================] - 232s 39ms/step - loss: 0.3473 - accuracy: 0.8628 - val_loss: 0.4463 - val_accuracy: 0.8980
# Epoch 4/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.3059 - accuracy: 0.8885 - val_loss: 0.4807 - val_accuracy: 0.8763
# Epoch 5/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.2229 - accuracy: 0.9155 - val_loss: 0.7685 - val_accuracy: 0.7424
# Epoch 6/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1837 - accuracy: 0.9310 - val_loss: 0.7212 - val_accuracy: 0.8246
# Epoch 7/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1685 - accuracy: 0.9351 - val_loss: 0.4532 - val_accuracy: 0.8980
# Epoch 8/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1484 - accuracy: 0.9395 - val_loss: 0.8723 - val_accuracy: 0.7709
# Epoch 9/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1318 - accuracy: 0.9514 - val_loss: 0.4397 - val_accuracy: 0.8865
# Epoch 10/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.1251 - accuracy: 0.9548 - val_loss: 0.5647 - val_accuracy: 0.8348
# Epoch 11/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1196 - accuracy: 0.9573 - val_loss: 0.6927 - val_accuracy: 0.8273
# Epoch 12/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0812 - accuracy: 0.9704 - val_loss: 0.6148 - val_accuracy: 0.8232
# Epoch 13/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.1029 - accuracy: 0.9640 - val_loss: 1.3127 - val_accuracy: 0.6873
# Epoch 14/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0856 - accuracy: 0.9667 - val_loss: 1.1920 - val_accuracy: 0.7899
# Epoch 15/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0653 - accuracy: 0.9719 - val_loss: 1.0087 - val_accuracy: 0.8171
# Epoch 16/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0762 - accuracy: 0.9726 - val_loss: 1.7170 - val_accuracy: 0.7220
# Epoch 17/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0597 - accuracy: 0.9748 - val_loss: 0.6061 - val_accuracy: 0.8572
# Epoch 18/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0555 - accuracy: 0.9765 - val_loss: 1.2807 - val_accuracy: 0.7682
# Epoch 19/20
# 5882/5882 [==============================] - 236s 40ms/step - loss: 0.0590 - accuracy: 0.9743 - val_loss: 1.6000 - val_accuracy: 0.7226
# Epoch 20/20
# 5882/5882 [==============================] - 237s 40ms/step - loss: 0.0646 - accuracy: 0.9750 - val_loss: 1.9857 - val_accuracy: 0.7050

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 3))
ax[0].plot(ThisModel.history['loss'], color='b', label="Training loss")
ax[0].plot(ThisModel.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(ThisModel.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(ThisModel.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
ModelLoss, ModelAccuracy = KerasModel.evaluate(X_test, y_test)

print('Test Loss is {}'.format(ModelLoss))
print('Test Accuracy is {}'.format(ModelAccuracy ))
# Out:
# 3475/3475 [==============================] - 39s 11ms/step
# Test Loss is 0.5676226793944255
# Test Accuracy is 0.9153956770896912

# %% [markdown]
# ### now to predict X test

# %%
y_pred = KerasModel.predict(X_test)

print('Prediction Shape is {}'.format(y_pred.shape))
# Out:
# Prediction Shape is (3475, 3)

# %% [markdown]
# great
#
# now it's time to redict X Predict

# %%
y_result = KerasModel.predict(X_pred_array)

print('Prediction Shape is {}'.format(y_result.shape))
# Out:
# Prediction Shape is (1669, 3)

# %% [markdown]
# ### and to show random redicted pictures & its predicting category

# %%
plt.figure(figsize=(20,20))
for n , i in enumerate(list(np.random.randint(0,len(X_pred),49))) : 
    plt.subplot(7,7,n+1)
    plt.imshow(X_pred[i])    
    plt.axis('off')
    plt.gray()
    plt.title(getcode(np.argmax(y_result[i])), fontsize=18)
